# %%
import os
import glob
import sys
import yaml

from tempest import casestudy
from tempest import grid
from tempest import handler
from tempest import joint_distrib
from tempest import storm_tracker

settings_path = 'settings/xshield_winter_30d.yaml'

workdir=os.getcwd()
print(workdir)
sys.path.append(workdir)

# Instantiate CaseStudy by passing the settings. 
# Should also create appropriate directories
hdlr = handler.Handler(settings_path)
overwrite = False
cs = casestudy.CaseStudy(hdlr, overwrite = overwrite ,verbose = True)
gr = grid.Grid(cs, fast = True, overwrite= overwrite, verbose_steps = False, verbose = False)
# jd.prec['mean_Prec_cond_50'] = jd.prec["cond_alpha_50_Prec"] / jd.prec["Sigma_cond_alpha_50_Prec"]
# jd.prec.to_netcdf("/scratchx/mcarenso/tempest/DYAMOND_SAM_post_20_days_Tropics/prec2.nc")

if __name__ == '__main__':
    # # # 1st batch 
    gr.compute_funcs_for_var_id("Prec", overwrite_var_id=True)
    gr.compute_funcs_for_var_id("MCS_label", overwrite_var_id=True)
    gr.compute_funcs_for_var_id("MCS_Feng", overwrite_var_id=True)
    
    print("Storm tracking clouds")
    st = storm_tracker.StormTracker(gr, label_var_id = "MCS_label", overwrite_storms = True, overwrite = False)
    print("Storm tracking mcs")
    st = storm_tracker.StormTracker(gr, label_var_id = "MCS_Feng", overwrite_storms = True, overwrite = False)

    # # 2nd batch
    # gr.compute_funcs_for_var_id("vDCS", overwrite_var_id=True)
    # gr.compute_funcs_for_var_id("MCS_cond_Prec_15")
    # gr.compute_funcs_for_var_id("vDCS_cond_Prec_15")
    # gr.compute_funcs_for_var_id("clouds_cond_Prec_15")
    # st = storm_tracker.StormTracker(gr, label_var_id = "vDCS", overwrite_storms = True, overwrite = False)

    # cloud_types = ["clouds_cond_prec_15", "vdcs_cond_prec_15", "mcs_cond_prec_15"]
    # for cloud_type in cloud_types:
    #     gr.build_cloud_intersect(cloud_type, coverage_threshold=0.5)


    # gr.compute_funcs_for_var_id("Prec_lowRes", overwrite_var_id=True)

    # gr.compute_funcs_for_var_id("sst", overwrite_var_id=True)

    # gr.compute_funcs_for_var_id("T2mm")

    # gr.compute_funcs_for_var_id("MCS_label", overwrite_var_id=True)

    # gr.compute_funcs_for_var_id("MCS_Feng", overwrite_var_id=True)
    
    # gr.compute_funcs_for_var_id("Conv_MCS_label", overwrite_var_id=True)

    # gr.compute_funcs_for_var_id("vDCS")
    # st = storm_tracker.StormTracker(gr, label_var_id = "vDCS", overwrite_storms = True, overwrite = False)

    # gr.compute_funcs_for_var_id("MCS_cond_Prec_15")
    # gr.compute_funcs_for_var_id("vDCS_cond_Prec_15")
    # gr.compute_funcs_for_var_id("clouds_cond_Prec_15")
    # gr.compute_funcs_for_var_id("sliding_clouds_cond_Prec_15")
    # gr.compute_funcs_for_var_id("sliding_mcs_cond_Prec_15")

    # gr.compute_funcs_for_var_id("vDCS_Strat_Prec",  overwrite_var_id=True)
    # gr.compute_funcs_for_var_id("vDCS_Conv_Prec", overwrite_var_id=True)
    # jd = joint_distrib.JointDistribution(gr, nd= 5, overwrite = False, storm_tracking = True)
    # jd.get_mcs_bin_fraction()
# Out:
# /home/mcarenso/code/tempest
# First instance of XSHiELD_Winter_lowRes_Tropics. It's directory has been created at : /scratchx/mcarenso/tempest/XSHiELD_Winter_lowRes_Tropics
# Creation of /scratchx/mcarenso/tempest/XSHiELD_Winter_lowRes_Tropics/var_id_days_i_t.json
# Prec
# MCS_cond_Prec_15
# vDCS_cond_Prec_15
# clouds_cond_Prec_15
# Variables data retrieved. Saving them in /scratchx/mcarenso/tempest/XSHiELD_Winter_lowRes_Tropics/var_id_days_i_t.json
# Data saved as /scratchx/mcarenso/tempest/XSHiELD_Winter_lowRes_Tropics/var_id_days_i_t.json
# pr
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# rlut
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# MCS_label
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# MCS_label_Tb_Feng
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# Conv_MCS_label
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# MCS_Feng
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# vDCS
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# vDCS_no_MCS
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# sst
# day:      (#t)  t_i-t_f
# 20-01-30: (1) 240-240
# 20-01-31: (1) 264-264
# 20-02-01: (1) 288-288
# 20-02-02: (1) 312-312
# 20-02-03: (1) 336-336
# 20-02-04: (1) 360-360
# 20-02-05: (1) 384-384
# 20-02-06: (1) 408-408
# 20-02-07: (1) 432-432
# 20-02-08: (1) 456-456
# 20-02-09: (1) 480-480
# 20-02-10: (1) 504-504
# 20-02-11: (1) 528-528
# 20-02-12: (1) 552-552
# 20-02-13: (1) 576-576
# 20-02-14: (1) 600-600
# 20-02-15: (1) 624-624
# 20-02-16: (1) 648-648
# 20-02-17: (1) 672-672
# 20-02-18: (1) 696-696
# 20-02-19: (1) 720-720
# 20-02-20: (1) 744-744
# 20-02-21: (1) 768-768
# 20-02-22: (1) 792-792
# 20-02-23: (1) 816-816
# 20-02-24: (1) 840-840
# 20-02-25: (1) 864-864
# 20-02-26: (1) 888-888
# 20-02-27: (1) 912-912
# 20-02-28: (1) 936-936
# Prec
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# MCS_cond_Prec_15
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# vDCS_cond_Prec_15
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
# clouds_cond_Prec_15
# day:      (#t)  t_i-t_f
# 20-01-30: (24) 240-263
# 20-01-31: (24) 264-287
# 20-02-01: (24) 288-311
# 20-02-02: (24) 312-335
# 20-02-03: (24) 336-359
# 20-02-04: (24) 360-383
# 20-02-05: (24) 384-407
# 20-02-06: (24) 408-431
# 20-02-07: (24) 432-455
# 20-02-08: (24) 456-479
# 20-02-09: (24) 480-503
# 20-02-10: (24) 504-527
# 20-02-11: (24) 528-551
# 20-02-12: (24) 552-575
# 20-02-13: (24) 576-599
# 20-02-14: (24) 600-623
# 20-02-15: (24) 624-647
# 20-02-16: (24) 648-671
# 20-02-17: (24) 672-695
# 20-02-18: (24) 696-719
# 20-02-19: (24) 720-743
# 20-02-20: (24) 744-767
# 20-02-21: (24) 768-791
# 20-02-22: (24) 792-815
# 20-02-23: (24) 816-839
# 20-02-24: (24) 840-863
# 20-02-25: (24) 864-887
# 20-02-26: (24) 888-911
# 20-02-27: (24) 912-935
# 20-02-28: (24) 936-959
#
#
# Making simpler grid
#
#  Woah,
#  the netcdf for this variable Prec didn't exist yet, let's make it from scratch :
#
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# compute [] again because of overwrite parameter
# These keys : ['cond_alpha_00_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_00_Prec', 'threshold_cond_alpha_00_Prec', 'Sigma_intra_day_cond_alpha_00_Prec', 'cond_alpha_01_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_01_Prec', 'threshold_cond_alpha_01_Prec', 'Sigma_intra_day_cond_alpha_01_Prec', 'cond_alpha_05_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_05_Prec', 'threshold_cond_alpha_05_Prec', 'Sigma_intra_day_cond_alpha_05_Prec', 'cond_alpha_10_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_10_Prec', 'threshold_cond_alpha_10_Prec', 'Sigma_intra_day_cond_alpha_10_Prec', 'cond_alpha_20_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_20_Prec', 'threshold_cond_alpha_20_Prec', 'Sigma_intra_day_cond_alpha_20_Prec', 'cond_alpha_25_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_25_Prec', 'threshold_cond_alpha_25_Prec', 'Sigma_intra_day_cond_alpha_25_Prec', 'cond_alpha_33_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_33_Prec', 'threshold_cond_alpha_33_Prec', 'Sigma_intra_day_cond_alpha_33_Prec', 'cond_alpha_40_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_40_Prec', 'threshold_cond_alpha_40_Prec', 'Sigma_intra_day_cond_alpha_40_Prec', 'cond_alpha_50_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_50_Prec', 'threshold_cond_alpha_50_Prec', 'Sigma_intra_day_cond_alpha_50_Prec', 'cond_alpha_60_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_60_Prec', 'threshold_cond_alpha_60_Prec', 'Sigma_intra_day_cond_alpha_60_Prec', 'cond_alpha_67_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_67_Prec', 'threshold_cond_alpha_67_Prec', 'Sigma_intra_day_cond_alpha_67_Prec', 'cond_alpha_75_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_75_Prec', 'threshold_cond_alpha_75_Prec', 'Sigma_intra_day_cond_alpha_75_Prec', 'cond_alpha_80_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_80_Prec', 'threshold_cond_alpha_80_Prec', 'Sigma_intra_day_cond_alpha_80_Prec', 'cond_alpha_85_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_85_Prec', 'threshold_cond_alpha_85_Prec', 'Sigma_intra_day_cond_alpha_85_Prec', 'cond_alpha_90_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_90_Prec', 'threshold_cond_alpha_90_Prec', 'Sigma_intra_day_cond_alpha_90_Prec', 'cond_alpha_95_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_95_Prec', 'threshold_cond_alpha_95_Prec', 'Sigma_intra_day_cond_alpha_95_Prec', 'cond_alpha_97_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_97_Prec', 'threshold_cond_alpha_97_Prec', 'Sigma_intra_day_cond_alpha_97_Prec', 'cond_alpha_99_Prec', 'mean_unweighted_Prec', 'Sigma_cond_alpha_99_Prec', 'threshold_cond_alpha_99_Prec', 'Sigma_intra_day_cond_alpha_99_Prec', 'convective_01_Prec', 'Alpha_convective_01_Prec', 'Sigma_convective_01_Prec', 'convective_02_Prec', 'Alpha_convective_02_Prec', 'Sigma_convective_02_Prec', 'convective_03_Prec', 'Alpha_convective_03_Prec', 'Sigma_convective_03_Prec', 'convective_04_Prec', 'Alpha_convective_04_Prec', 'Sigma_convective_04_Prec', 'convective_05_Prec', 'Alpha_convective_05_Prec', 'Sigma_convective_05_Prec', 'convective_06_Prec', 'Alpha_convective_06_Prec', 'Sigma_convective_06_Prec', 'convective_08_Prec', 'Alpha_convective_08_Prec', 'Sigma_convective_08_Prec', 'convective_10_Prec', 'Alpha_convective_10_Prec', 'Sigma_convective_10_Prec', 'convective_12_Prec', 'Alpha_convective_12_Prec', 'Sigma_convective_12_Prec', 'convective_15_Prec', 'Alpha_convective_15_Prec', 'Sigma_convective_15_Prec', 'convective_20_Prec', 'Alpha_convective_20_Prec', 'Sigma_convective_20_Prec', 'convective_25_Prec', 'Alpha_convective_25_Prec', 'Sigma_convective_25_Prec', 'convective_30_Prec', 'Alpha_convective_30_Prec', 'Sigma_convective_30_Prec', 'convective_40_Prec', 'Alpha_convective_40_Prec', 'Sigma_convective_40_Prec', 'convective_50_Prec', 'Alpha_convective_50_Prec', 'Sigma_convective_50_Prec', 'max_Prec'] have to be computed.
#
#  computing day 20-01-30 for funcs ['cond_alpha_00', 'cond_alpha_01', 'cond_alpha_05', 'cond_alpha_10', 'cond_alpha_20', 'cond_alpha_25', 'cond_alpha_33', 'cond_alpha_40', 'cond_alpha_50', 'cond_alpha_60', 'cond_alpha_67', 'cond_alpha_75', 'cond_alpha_80', 'cond_alpha_85', 'cond_alpha_90', 'cond_alpha_95', 'cond_alpha_97', 'cond_alpha_99', 'convective_01', 'convective_02', 'convective_03', 'convective_04', 'convective_05', 'convective_06', 'convective_08', 'convective_10', 'convective_12', 'convective_15', 'convective_20', 'convective_25', 'convective_30', 'convective_40', 'convective_50', 'max']
# loading whole day data for day 20-01-30 for alpha_cond
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# MCSMIP Model prec
# compute alpha_cond for threshold 0.0
# compute alpha_cond for threshold 0.01
# compute alpha_cond for threshold 0.05
# compute alpha_cond for threshold 0.1
# compute alpha_cond for threshold 0.2
# compute alpha_cond for threshold 0.25
# compute alpha_cond for threshold 0.33
# compute alpha_cond for threshold 0.4
# compute alpha_cond for threshold 0.5
# compute alpha_cond for threshold 0.6
# compute alpha_cond for threshold 0.67
# compute alpha_cond for threshold 0.75
# compute alpha_cond for threshold 0.8
# compute alpha_cond for threshold 0.85
# compute alpha_cond for threshold 0.9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 29
#      24 # jd.prec['mean_Prec_cond_50'] = jd.prec["cond_alpha_50_Prec"] / jd.prec["Sigma_cond_alpha_50_Prec"]
#      25 # jd.prec.to_netcdf("/scratchx/mcarenso/tempest/DYAMOND_SAM_post_20_days_Tropics/prec2.nc")
#      27 if __name__ == '__main__':
#      28     # # # 1st batch
# ---> 29     gr.compute_funcs_for_var_id("Prec", overwrite_var_id=True)
#      30     gr.compute_funcs_for_var_id("MCS_label", overwrite_var_id=True)
#      31     gr.compute_funcs_for_var_id("MCS_Feng", overwrite_var_id=True)
#
# File ~/code/tempest/tempest/grid.py:530, in Grid.compute_funcs_for_var_id(self, var_id, overwrite_var_id)
#     528 for day in days:
#     529     print(f"\n computing day {day} for funcs {funcs_to_compute}")
# --> 530     da_funcs = self.regrid_funcs_and_save_by_day(day, var_id, funcs_to_compute)
#     531     # if heavy is in funcs_to_compute, da_funcs will naturally have 4 items as if 3 more funcs but it's just 4 different keys
#     532     for i_f, da_func in enumerate(da_funcs):
#
# File ~/code/tempest/tempest/grid.py:564, in Grid.regrid_funcs_and_save_by_day(self, day, var_id, funcs)
#     560 """
#     561 Compute multiple functions on new grid for a given day
#     562 """
#     563 outputs_da = [] ##list of full day DataArray for each func (so typically of len 1 for MCS_label, 2 for any variable, 3 for Prec)
# --> 564 var_regridded_per_funcs = self.regrid_funcs_for_day(day, var_id=var_id, funcs_to_compute=funcs)
#     566 for var_regridded in  var_regridded_per_funcs:
#     567     if var_id in self.cloud_vars:
#
# File ~/code/tempest/tempest/grid.py:643, in Grid.regrid_funcs_for_day(self, day, var_id, funcs_to_compute)
#     641     for threshold in threshold_alpha:
#     642         print("compute alpha_cond for threshold", threshold)
# --> 643         day_per_diag += self.get_cumsum_data_from_center_to_global(var_day, i_t_within_day, threshold)
#     645 if convective_cond_bool:
#     646     for threshold in threshold_convective:
#
# File ~/code/tempest/tempest/grid.py:919, in Grid.get_cumsum_data_from_center_to_global(self, data_on_center, i_t_within_day, threshold)
#     917 sigma_time = []
#     918 for t in range(np.shape(x[:, slice_i_lat, slice_j_lon])[0]):
# --> 919     x_t_subset_dirty = x[t, slice_i_lat, slice_j_lon].flatten()
#     920     x_t_subset = x_t_subset_dirty[~np.isnan(x_t_subset_dirty)]
#     921     sigma_t = np.nansum(x_t_subset>pcond)/len(x_t_subset)
#
# KeyboardInterrupt:
